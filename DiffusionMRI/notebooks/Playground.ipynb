# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
a = np.load("/home/agajan/experiment_DiffusionMRI/tractseg_data/784565/pca_stats_norm.npz")
b = np.load("/home/agajan/experiment_DiffusionMRI/tractseg_data/784565/pca_stats_unnorm.npz")

# %%
plt.plot(a["n_components"], a["scores"], label="norm")
plt.plot(b["n_components"], b["scores"], label="unnorm")
plt.legend()

# %%
a["scores"], a["scores"][21]
# Out:
# (array([0.15600681, 0.2657671 , 0.30074918, 0.3189475 , 0.35671157,
#         0.38978   , 0.39730388, 0.41063568, 0.43890193, 0.43473516,
#         0.43933258, 0.43816937, 0.44546949, 0.4466276 , 0.43628988,
#         0.44373174, 0.44178744, 0.44799594, 0.44267482, 0.44082709,
#         0.44191907, 0.44027997, 0.43634676, 0.43778298, 0.44034994,
#         0.43601754, 0.43494687, 0.43179932, 0.43775195]), 0.440279965367949)
